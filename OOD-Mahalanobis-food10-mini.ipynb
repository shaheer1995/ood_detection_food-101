# %%
# !git clone 'https://github.com/shaheer1995/deep_Mahalanobis_detector-V2'
# Out:
# Cloning into 'deep_Mahalanobis_detector-V2'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 37 (delta 4), reused 37 (delta 4), pack-reused 0
# Unpacking objects: 100% (37/37), done.

# %%
# %cd deep_Mahalanobis_detector-V2/
# Out:
# /content/deep_Mahalanobis_detector-V2

# %%
# %mkdir data

# %%
# %cd data
# Out:
# /content/deep_Mahalanobis_detector-V2/data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# %cd /content/deep_Mahalanobis_detector-V2/
# %mkdir pre_trained

# %cd /content/drive/My\ Drive/Research/food-models/
# !cp res50_model_checkpoint-2.pth /content/deep_Mahalanobis_detector-V2/pre_trained/
# %cd /content/deep_Mahalanobis_detector-V2/pre_trained/
# !ls

# %cd /content/drive/My\ Drive/Research/OOD_Detector/pre_trained
# !cp resnet_cifar10.pth /content/deep_Mahalanobis_detector-V2/pre_trained/
# %cd /content/deep_Mahalanobis_detector-V2/pre_trained/
# !ls
# Out:
# /content/ood-metrics
# /content/deep_Mahalanobis_detector-V2
# mkdir: cannot create directory ‘pre_trained’: File exists
# /content/drive/My Drive/Research/food-models
# /content/deep_Mahalanobis_detector-V2/pre_trained
# res50_model_checkpoint-2.pth
# /content/drive/My Drive/Research/OOD_Detector/pre_trained
# /content/deep_Mahalanobis_detector-V2/pre_trained
# res50_model_checkpoint-2.pth  resnet_cifar10.pth

# %%
# %cd /content/deep_Mahalanobis_detector-V2
# Out:
# /content/deep_Mahalanobis_detector-V2

# %%
# Load the network

from __future__ import print_function
import argparse
import torch
import data_loader
import numpy as np
import calculate_log as callog
import models
import os
import lib_generation
from torchvision import datasets, transforms, models
from torchvision import transforms
from torch.autograd import Variable
from torch import nn

# set the path to pre-trained model and output
pre_trained_net = './pre_trained/res50_model_checkpoint-2.pth'

torch.cuda.set_device(0)

# check the in-distribution dataset
out_dist_list = ['svhn', 'imagenet_resize', 'lsun_resize']

# load networks
# model = models.ResNet50()
# model.load_state_dict(torch.load(pre_trained_net, map_location = "cuda:" + str(0)))
# in_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])
# Use the same architecture as used earlier
checkpoint = torch.load(pre_trained_net,  map_location = "cuda:" + str(0))
model = models.resnet50(pretrained=False)
for param in model.parameters():
  param.requires_grad = False

    
classifier = nn.Linear(2048, 10)
model.fc = classifier

model.load_state_dict(checkpoint['model_state'], strict=False)
in_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])
model.cuda()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )

# %%
# Check the saved model's last epoch and last validation loss
valid_loss = checkpoint["valid_loss_min"] 
num_epoch = checkpoint['epochs']

print(num_epoch)
print(valid_loss)
# Out:
# 27
# 0.2940021837234497

# %%
# %cd /content/drive/My\ Drive/datasets/
# !ls
# !cp food-10-mini.zip /content/deep_Mahalanobis_detector-V2/data/
# Out:
# /content/drive/My Drive/datasets
# food101		   food-101-mini      food-10-mini
# food101-Inference  food-101-mini.zip  food-10-mini.zip

# %%
# %cd /content/deep_Mahalanobis_detector-V2/data/
# !unzip food-10-mini.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: food-10-mini/images/french_fries/106608.jpg
#   inflating: food-10-mini/images/french_fries/1071481.jpg
#   inflating: food-10-mini/images/french_fries/107312.jpg
#   inflating: food-10-mini/images/french_fries/1074446.jpg
#   inflating: food-10-mini/images/french_fries/1078563.jpg
#   inflating: food-10-mini/images/french_fries/1080215.jpg
#   inflating: food-10-mini/images/french_fries/1081387.jpg
#   inflating: food-10-mini/images/french_fries/1083531.jpg
#   inflating: food-10-mini/images/french_fries/1085071.jpg
#   inflating: food-10-mini/images/french_fries/108743.jpg
#   inflating: food-10-mini/images/french_fries/1089500.jpg
#   inflating: food-10-mini/images/french_fries/10897.jpg
#   inflating: food-10-mini/images/french_fries/1093724.jpg
#   inflating: food-10-mini/images/french_fries/109401.jpg
#   inflating: food-10-mini/images/french_fries/1099260.jpg
#   inflating: food-10-mini/images/french_fries/1099329.jpg
#   inflating: food-10-mini/images/french_fries/1101970.jpg
#   inflating: food-10-mini/images/french_fries/1102783.jpg
#   inflating: food-10-mini/images/french_fries/110385.jpg
#   inflating: food-10-mini/images/french_fries/1112960.jpg
#   inflating: food-10-mini/images/french_fries/1116093.jpg
#   inflating: food-10-mini/images/french_fries/112309.jpg
#   inflating: food-10-mini/images/french_fries/1126453.jpg
#   inflating: food-10-mini/images/french_fries/1129645.jpg
#   inflating: food-10-mini/images/french_fries/1131104.jpg
#   inflating: food-10-mini/images/french_fries/1132539.jpg
#   inflating: food-10-mini/images/french_fries/1133382.jpg
#   inflating: food-10-mini/images/french_fries/1138037.jpg
#   inflating: food-10-mini/images/french_fries/114269.jpg
#   inflating: food-10-mini/images/french_fries/1150103.jpg
#   inflating: food-10-mini/images/french_fries/1165966.jpg
#   inflating: food-10-mini/images/french_fries/1177340.jpg
#   inflating: food-10-mini/images/french_fries/1190903.jpg
#   inflating: food-10-mini/images/french_fries/1191743.jpg
#   inflating: food-10-mini/images/french_fries/1192860.jpg
#   inflating: food-10-mini/images/french_fries/1197437.jpg
#   inflating: food-10-mini/images/french_fries/1198412.jpg
#   inflating: food-10-mini/images/french_fries/1199754.jpg
#   inflating: food-10-mini/images/french_fries/1209297.jpg
#   inflating: food-10-mini/images/french_fries/1215903.jpg
#   inflating: food-10-mini/images/french_fries/1219252.jpg
#   inflating: food-10-mini/images/french_fries/1221000.jpg
#   inflating: food-10-mini/images/french_fries/1234305.jpg
#   inflating: food-10-mini/images/french_fries/1238390.jpg
#   inflating: food-10-mini/images/french_fries/123902.jpg
#   inflating: food-10-mini/images/french_fries/123929.jpg
#   inflating: food-10-mini/images/french_fries/1241462.jpg
#   inflating: food-10-mini/images/french_fries/1243254.jpg
#   inflating: food-10-mini/images/french_fries/1251079.jpg
#   inflating: food-10-mini/images/french_fries/1257345.jpg
#   inflating: food-10-mini/images/french_fries/1258546.jpg
#   inflating: food-10-mini/images/french_fries/1264270.jpg
#   inflating: food-10-mini/images/french_fries/1267026.jpg
#   inflating: food-10-mini/images/french_fries/1269687.jpg
#   inflating: food-10-mini/images/french_fries/1273478.jpg
#   inflating: food-10-mini/images/french_fries/1290768.jpg
#   inflating: food-10-mini/images/french_fries/1290860.jpg
#   inflating: food-10-mini/images/french_fries/1295274.jpg
#   inflating: food-10-mini/images/french_fries/1306987.jpg
#   inflating: food-10-mini/images/french_fries/1316819.jpg
#   inflating: food-10-mini/images/french_fries/1319764.jpg
#   inflating: food-10-mini/images/french_fries/1327248.jpg
#   inflating: food-10-mini/images/french_fries/1337228.jpg
#   inflating: food-10-mini/images/french_fries/1337938.jpg
#   inflating: food-10-mini/images/french_fries/1341912.jpg
#   inflating: food-10-mini/images/french_fries/1343675.jpg
#   inflating: food-10-mini/images/french_fries/1345833.jpg
#   inflating: food-10-mini/images/french_fries/1346017.jpg
#   inflating: food-10-mini/images/french_fries/1347228.jpg
#   inflating: food-10-mini/images/french_fries/1348209.jpg
#   inflating: food-10-mini/images/french_fries/1361604.jpg
#   inflating: food-10-mini/images/french_fries/1364015.jpg
#   inflating: food-10-mini/images/french_fries/1369116.jpg
#   inflating: food-10-mini/images/french_fries/1370900.jpg
#   inflating: food-10-mini/images/french_fries/1376608.jpg
#   inflating: food-10-mini/images/french_fries/1384733.jpg
#   inflating: food-10-mini/images/french_fries/1387352.jpg
#   inflating: food-10-mini/images/french_fries/1388756.jpg
#   inflating: food-10-mini/images/french_fries/1394977.jpg
#   inflating: food-10-mini/images/french_fries/1424609.jpg
#   inflating: food-10-mini/images/french_fries/1426779.jpg
#   inflating: food-10-mini/images/french_fries/143158.jpg
#   inflating: food-10-mini/images/french_fries/143685.jpg
#   inflating: food-10-mini/images/french_fries/1437118.jpg
#   inflating: food-10-mini/images/french_fries/1438129.jpg
#   inflating: food-10-mini/images/french_fries/1439792.jpg
#   inflating: food-10-mini/images/french_fries/1439886.jpg
#   inflating: food-10-mini/images/french_fries/143994.jpg
#   inflating: food-10-mini/images/french_fries/1443088.jpg
#   inflating: food-10-mini/images/french_fries/1443762.jpg
#   inflating: food-10-mini/images/french_fries/1447440.jpg
#   inflating: food-10-mini/images/french_fries/145012.jpg
#   inflating: food-10-mini/images/french_fries/1453873.jpg
#   inflating: food-10-mini/images/french_fries/146029.jpg
#   inflating: food-10-mini/images/french_fries/1469308.jpg
#   inflating: food-10-mini/images/french_fries/1475332.jpg
#   inflating: food-10-mini/images/french_fries/147628.jpg
#   inflating: food-10-mini/images/french_fries/1480588.jpg
#   inflating: food-10-mini/images/french_fries/149278.jpg
#   inflating: food-10-mini/images/french_fries/1495592.jpg
#   inflating: food-10-mini/images/french_fries/1495836.jpg
#   inflating: food-10-mini/images/french_fries/1504529.jpg
#   inflating: food-10-mini/images/french_fries/1505018.jpg
#   inflating: food-10-mini/images/french_fries/1509620.jpg
#   inflating: food-10-mini/images/french_fries/1510273.jpg
#   inflating: food-10-mini/images/french_fries/1519669.jpg
#   inflating: food-10-mini/images/french_fries/1521274.jpg
#   inflating: food-10-mini/images/french_fries/1523716.jpg
#   inflating: food-10-mini/images/french_fries/152498.jpg
#   inflating: food-10-mini/images/french_fries/1528250.jpg
#   inflating: food-10-mini/images/french_fries/1531073.jpg
#   inflating: food-10-mini/images/french_fries/153648.jpg
#   inflating: food-10-mini/images/french_fries/153823.jpg
#   inflating: food-10-mini/images/french_fries/1538500.jpg
#   inflating: food-10-mini/images/french_fries/1541766.jpg
#   inflating: food-10-mini/images/french_fries/1552191.jpg
#   inflating: food-10-mini/images/french_fries/1555814.jpg
#   inflating: food-10-mini/images/french_fries/1564138.jpg
#   inflating: food-10-mini/images/french_fries/1571407.jpg
#   inflating: food-10-mini/images/french_fries/1577236.jpg
#   inflating: food-10-mini/images/french_fries/1580419.jpg
#   inflating: food-10-mini/images/french_fries/1582025.jpg
#   inflating: food-10-mini/images/french_fries/1593676.jpg
#   inflating: food-10-mini/images/french_fries/1595244.jpg
#   inflating: food-10-mini/images/french_fries/1596441.jpg
#   inflating: food-10-mini/images/french_fries/1606755.jpg
#   inflating: food-10-mini/images/french_fries/1610240.jpg
#   inflating: food-10-mini/images/french_fries/1615596.jpg
#   inflating: food-10-mini/images/french_fries/1617899.jpg
#   inflating: food-10-mini/images/french_fries/1622796.jpg
#   inflating: food-10-mini/images/french_fries/1625531.jpg
#   inflating: food-10-mini/images/french_fries/1636661.jpg
#   inflating: food-10-mini/images/french_fries/1637064.jpg
#   inflating: food-10-mini/images/french_fries/1639700.jpg
#   inflating: food-10-mini/images/french_fries/1642141.jpg
#   inflating: food-10-mini/images/french_fries/164288.jpg
#   inflating: food-10-mini/images/french_fries/1647142.jpg
#   inflating: food-10-mini/images/french_fries/1648775.jpg
#   inflating: food-10-mini/images/french_fries/1653893.jpg
#   inflating: food-10-mini/images/french_fries/1656352.jpg
#   inflating: food-10-mini/images/french_fries/1659097.jpg
#   inflating: food-10-mini/images/french_fries/1667108.jpg
#   inflating: food-10-mini/images/french_fries/166821.jpg
#   inflating: food-10-mini/images/french_fries/1676299.jpg
#   inflating: food-10-mini/images/french_fries/1681867.jpg
#   inflating: food-10-mini/images/french_fries/1682173.jpg
#   inflating: food-10-mini/images/french_fries/168924.jpg
#   inflating: food-10-mini/images/french_fries/1692353.jpg
#   inflating: food-10-mini/images/french_fries/1692647.jpg
#   inflating: food-10-mini/images/french_fries/1694219.jpg
#   inflating: food-10-mini/images/french_fries/1697346.jpg
#   inflating: food-10-mini/images/french_fries/1697975.jpg
#   inflating: food-10-mini/images/french_fries/1700344.jpg
#   inflating: food-10-mini/images/french_fries/1703696.jpg
#   inflating: food-10-mini/images/french_fries/1703753.jpg
#   inflating: food-10-mini/images/french_fries/1708934.jpg
#   inflating: food-10-mini/images/french_fries/1709793.jpg
#   inflating: food-10-mini/images/french_fries/1712331.jpg
#   inflating: food-10-mini/images/french_fries/172042.jpg
#   inflating: food-10-mini/images/french_fries/1724805.jpg
#   inflating: food-10-mini/images/french_fries/1732161.jpg
#   inflating: food-10-mini/images/french_fries/17394.jpg
#   inflating: food-10-mini/images/french_fries/1740113.jpg
#   inflating: food-10-mini/images/french_fries/1745333.jpg
#   inflating: food-10-mini/images/french_fries/174977.jpg
#   inflating: food-10-mini/images/french_fries/1763119.jpg
#   inflating: food-10-mini/images/french_fries/1767804.jpg
#   inflating: food-10-mini/images/french_fries/1767923.jpg
#   inflating: food-10-mini/images/french_fries/1772112.jpg
#   inflating: food-10-mini/images/french_fries/1772806.jpg
#   inflating: food-10-mini/images/french_fries/177372.jpg
#   inflating: food-10-mini/images/french_fries/1776346.jpg
#   inflating: food-10-mini/images/french_fries/1778153.jpg
#   inflating: food-10-mini/images/french_fries/1781706.jpg
#   inflating: food-10-mini/images/french_fries/1785605.jpg
#   inflating: food-10-mini/images/french_fries/1787214.jpg
#   inflating: food-10-mini/images/french_fries/1787600.jpg
#   inflating: food-10-mini/images/french_fries/1793704.jpg
#   inflating: food-10-mini/images/french_fries/1810007.jpg
#   inflating: food-10-mini/images/french_fries/1810352.jpg
#   inflating: food-10-mini/images/french_fries/1813453.jpg
#   inflating: food-10-mini/images/french_fries/1816442.jpg
#   inflating: food-10-mini/images/french_fries/1845621.jpg
#   inflating: food-10-mini/images/french_fries/184954.jpg
#   inflating: food-10-mini/images/french_fries/1850310.jpg
#   inflating: food-10-mini/images/french_fries/1850835.jpg
#   inflating: food-10-mini/images/french_fries/1855221.jpg
#   inflating: food-10-mini/images/french_fries/1855501.jpg
#   inflating: food-10-mini/images/french_fries/187087.jpg
#   inflating: food-10-mini/images/french_fries/1875469.jpg
#   inflating: food-10-mini/images/french_fries/1875986.jpg
#   inflating: food-10-mini/images/french_fries/1877099.jpg
#   inflating: food-10-mini/images/french_fries/1888134.jpg
#   inflating: food-10-mini/images/french_fries/1897333.jpg
#   inflating: food-10-mini/images/french_fries/1898017.jpg
#   inflating: food-10-mini/images/french_fries/1901621.jpg
#   inflating: food-10-mini/images/french_fries/1905719.jpg
#   inflating: food-10-mini/images/french_fries/1909354.jpg
#   inflating: food-10-mini/images/french_fries/191085.jpg
#   inflating: food-10-mini/images/french_fries/1923345.jpg
#   inflating: food-10-mini/images/french_fries/1923452.jpg
#   inflating: food-10-mini/images/french_fries/1926251.jpg
#   inflating: food-10-mini/images/french_fries/192632.jpg
#   inflating: food-10-mini/images/french_fries/1928448.jpg
#   inflating: food-10-mini/images/french_fries/1928660.jpg
#   inflating: food-10-mini/images/french_fries/1929717.jpg
#   inflating: food-10-mini/images/french_fries/1934980.jpg
#   inflating: food-10-mini/images/french_fries/1936184.jpg
#   inflating: food-10-mini/images/french_fries/1937830.jpg
#   inflating: food-10-mini/images/french_fries/194973.jpg
#   inflating: food-10-mini/images/french_fries/1958538.jpg
#   inflating: food-10-mini/images/french_fries/1958884.jpg
#   inflating: food-10-mini/images/french_fries/1959790.jpg
#   inflating: food-10-mini/images/french_fries/1969264.jpg
#   inflating: food-10-mini/images/french_fries/1970888.jpg
#   inflating: food-10-mini/images/french_fries/1973780.jpg
#   inflating: food-10-mini/images/french_fries/1974930.jpg
#   inflating: food-10-mini/images/french_fries/1987038.jpg
#   inflating: food-10-mini/images/french_fries/1987068.jpg
#   inflating: food-10-mini/images/french_fries/1987093.jpg
#   inflating: food-10-mini/images/french_fries/1998271.jpg
#   inflating: food-10-mini/images/french_fries/2001007.jpg
#   inflating: food-10-mini/images/french_fries/200168.jpg
#   inflating: food-10-mini/images/french_fries/2001882.jpg
#   inflating: food-10-mini/images/french_fries/2001959.jpg
#   inflating: food-10-mini/images/french_fries/2004116.jpg
#   inflating: food-10-mini/images/french_fries/200553.jpg
#   inflating: food-10-mini/images/french_fries/2008616.jpg
#   inflating: food-10-mini/images/french_fries/2011974.jpg
#   inflating: food-10-mini/images/french_fries/201362.jpg
#   inflating: food-10-mini/images/french_fries/2015613.jpg
#   inflating: food-10-mini/images/french_fries/20215.jpg
#   inflating: food-10-mini/images/french_fries/2029107.jpg
#   inflating: food-10-mini/images/french_fries/2029410.jpg
#   inflating: food-10-mini/images/french_fries/2031719.jpg
#   inflating: food-10-mini/images/french_fries/2039103.jpg
#   inflating: food-10-mini/images/french_fries/203924.jpg
#   inflating: food-10-mini/images/french_fries/2040049.jpg
#   inflating: food-10-mini/images/french_fries/204100.jpg
#   inflating: food-10-mini/images/french_fries/204132.jpg
#   inflating: food-10-mini/images/french_fries/2041482.jpg
#   inflating: food-10-mini/images/french_fries/2042971.jpg
#   inflating: food-10-mini/images/french_fries/2045577.jpg
#   inflating: food-10-mini/images/french_fries/2048963.jpg
#   inflating: food-10-mini/images/french_fries/2050364.jpg
#   inflating: food-10-mini/images/french_fries/2056007.jpg
#   inflating: food-10-mini/images/french_fries/2062301.jpg
#   inflating: food-10-mini/images/french_fries/2062357.jpg
#   inflating: food-10-mini/images/french_fries/2072514.jpg
#   inflating: food-10-mini/images/french_fries/2073415.jpg
#   inflating: food-10-mini/images/french_fries/2074075.jpg
#   inflating: food-10-mini/images/french_fries/2077845.jpg
#   inflating: food-10-mini/images/french_fries/2078820.jpg
#   inflating: food-10-mini/images/french_fries/2080959.jpg
#   inflating: food-10-mini/images/french_fries/2082676.jpg
#   inflating: food-10-mini/images/french_fries/2091683.jpg
#   inflating: food-10-mini/images/french_fries/2093557.jpg
#   inflating: food-10-mini/images/french_fries/2093949.jpg
#   inflating: food-10-mini/images/french_fries/2099094.jpg
#   inflating: food-10-mini/images/french_fries/2106366.jpg
#   inflating: food-10-mini/images/french_fries/211973.jpg
#   inflating: food-10-mini/images/french_fries/2121537.jpg
#   inflating: food-10-mini/images/french_fries/212348.jpg
#   inflating: food-10-mini/images/french_fries/2126499.jpg
#   inflating: food-10-mini/images/french_fries/2127530.jpg
#   inflating: food-10-mini/images/french_fries/2128557.jpg
#   inflating: food-10-mini/images/french_fries/2146228.jpg
#   inflating: food-10-mini/images/french_fries/2147046.jpg
#   inflating: food-10-mini/images/french_fries/2149566.jpg
#   inflating: food-10-mini/images/french_fries/2150187.jpg
#   inflating: food-10-mini/images/french_fries/2154538.jpg
#   inflating: food-10-mini/images/french_fries/2169308.jpg
#   inflating: food-10-mini/images/french_fries/2169665.jpg
#   inflating: food-10-mini/images/french_fries/2182834.jpg
#   inflating: food-10-mini/images/french_fries/2189231.jpg
#   inflating: food-10-mini/images/french_fries/2195192.jpg
#   inflating: food-10-mini/images/french_fries/2195953.jpg
#   inflating: food-10-mini/images/french_fries/2200585.jpg
#   inflating: food-10-mini/images/french_fries/2208648.jpg
#   inflating: food-10-mini/images/french_fries/2212633.jpg
#   inflating: food-10-mini/images/french_fries/2213664.jpg
#   inflating: food-10-mini/images/french_fries/2213917.jpg
#   inflating: food-10-mini/images/french_fries/2214535.jpg
#   inflating: food-10-mini/images/french_fries/2214673.jpg
#   inflating: food-10-mini/images/french_fries/2215693.jpg
#   inflating: food-10-mini/images/french_fries/2217120.jpg
#   inflating: food-10-mini/images/french_fries/2219197.jpg
#   inflating: food-10-mini/images/french_fries/2224231.jpg
#   inflating: food-10-mini/images/french_fries/2226284.jpg
#   inflating: food-10-mini/images/french_fries/2227296.jpg
#   inflating: food-10-mini/images/french_fries/2229500.jpg
#   inflating: food-10-mini/images/french_fries/223676.jpg
#   inflating: food-10-mini/images/french_fries/2239316.jpg
#   inflating: food-10-mini/images/french_fries/2239352.jpg
#   inflating: food-10-mini/images/french_fries/223944.jpg
#   inflating: food-10-mini/images/french_fries/2239479.jpg
#   inflating: food-10-mini/images/french_fries/2246161.jpg
#   inflating: food-10-mini/images/french_fries/2246387.jpg
#   inflating: food-10-mini/images/french_fries/2246621.jpg
#   inflating: food-10-mini/images/french_fries/2248373.jpg
#   inflating: food-10-mini/images/french_fries/2249089.jpg
#   inflating: food-10-mini/images/french_fries/2249607.jpg
#   inflating: food-10-mini/images/french_fries/2250693.jpg
#   inflating: food-10-mini/images/french_fries/2262956.jpg
#   inflating: food-10-mini/images/french_fries/2269039.jpg
#   inflating: food-10-mini/images/french_fries/2271466.jpg
#   inflating: food-10-mini/images/french_fries/2275484.jpg
#   inflating: food-10-mini/images/french_fries/2278380.jpg
#   inflating: food-10-mini/images/french_fries/2278633.jpg
#   inflating: food-10-mini/images/french_fries/2279576.jpg
#   inflating: food-10-mini/images/french_fries/2293554.jpg
#   inflating: food-10-mini/images/french_fries/2298765.jpg
#   inflating: food-10-mini/images/french_fries/230015.jpg
#   inflating: food-10-mini/images/french_fries/2301475.jpg
#   inflating: food-10-mini/images/french_fries/2303073.jpg
#   inflating: food-10-mini/images/french_fries/2307202.jpg
#   inflating: food-10-mini/images/french_fries/2309622.jpg
#   inflating: food-10-mini/images/french_fries/2313315.jpg
#   inflating: food-10-mini/images/french_fries/2314805.jpg
#   inflating: food-10-mini/images/french_fries/2315325.jpg
#   inflating: food-10-mini/images/french_fries/2325575.jpg
#   inflating: food-10-mini/images/french_fries/2331134.jpg
#   inflating: food-10-mini/images/french_fries/233172.jpg
#   inflating: food-10-mini/images/french_fries/2335210.jpg
#   inflating: food-10-mini/images/french_fries/2338175.jpg
#   inflating: food-10-mini/images/french_fries/2343991.jpg
#   inflating: food-10-mini/images/french_fries/2345519.jpg
#   inflating: food-10-mini/images/french_fries/234706.jpg
#   inflating: food-10-mini/images/french_fries/2348229.jpg
#   inflating: food-10-mini/images/french_fries/2348318.jpg
#   inflating: food-10-mini/images/french_fries/2348992.jpg
#   inflating: food-10-mini/images/french_fries/2350833.jpg
#   inflating: food-10-mini/images/french_fries/2355379.jpg
#   inflating: food-10-mini/images/french_fries/2357939.jpg
#   inflating: food-10-mini/images/french_fries/2361094.jpg
#   inflating: food-10-mini/images/french_fries/2361623.jpg
#   inflating: food-10-mini/images/french_fries/2369424.jpg
#   inflating: food-10-mini/images/french_fries/2369999.jpg
#   inflating: food-10-mini/images/french_fries/2370084.jpg
#   inflating: food-10-mini/images/french_fries/2371507.jpg
#   inflating: food-10-mini/images/french_fries/2371960.jpg
#   inflating: food-10-mini/images/french_fries/2382614.jpg
#   inflating: food-10-mini/images/french_fries/238410.jpg
#   inflating: food-10-mini/images/french_fries/2385210.jpg
#   inflating: food-10-mini/images/french_fries/2389101.jpg
#   inflating: food-10-mini/images/french_fries/2394139.jpg
#   inflating: food-10-mini/images/french_fries/2398418.jpg
#   inflating: food-10-mini/images/french_fries/2406476.jpg
#   inflating: food-10-mini/images/french_fries/240760.jpg
#   inflating: food-10-mini/images/french_fries/2413615.jpg
#   inflating: food-10-mini/images/french_fries/2414771.jpg
#   inflating: food-10-mini/images/french_fries/2418455.jpg
#   inflating: food-10-mini/images/french_fries/2429892.jpg
#   inflating: food-10-mini/images/french_fries/244006.jpg
#   inflating: food-10-mini/images/french_fries/24479.jpg
#   inflating: food-10-mini/images/french_fries/2449370.jpg
#   inflating: food-10-mini/images/french_fries/2452990.jpg
#   inflating: food-10-mini/images/french_fries/2454970.jpg
#   inflating: food-10-mini/images/french_fries/2464961.jpg
#   inflating: food-10-mini/images/french_fries/2472499.jpg
#   inflating: food-10-mini/images/french_fries/2476066.jpg
#   inflating: food-10-mini/images/french_fries/2479034.jpg
#   inflating: food-10-mini/images/french_fries/2483067.jpg
#   inflating: food-10-mini/images/french_fries/2485920.jpg
#   inflating: food-10-mini/images/french_fries/2487311.jpg
#   inflating: food-10-mini/images/french_fries/2490548.jpg
#   inflating: food-10-mini/images/french_fries/2493036.jpg
#   inflating: food-10-mini/images/french_fries/2497101.jpg
#   inflating: food-10-mini/images/french_fries/2497428.jpg
#   inflating: food-10-mini/images/french_fries/2498356.jpg
#   inflating: food-10-mini/images/french_fries/2502370.jpg
#   inflating: food-10-mini/images/french_fries/2502894.jpg
#   inflating: food-10-mini/images/french_fries/2503834.jpg
#   inflating: food-10-mini/images/french_fries/2507866.jpg
#   inflating: food-10-mini/images/french_fries/2510721.jpg
#   inflating: food-10-mini/images/french_fries/251128.jpg
#   inflating: food-10-mini/images/french_fries/2512097.jpg
#   inflating: food-10-mini/images/french_fries/2515183.jpg
#   inflating: food-10-mini/images/french_fries/2515440.jpg
#   inflating: food-10-mini/images/french_fries/2521012.jpg
#   inflating: food-10-mini/images/french_fries/2521724.jpg
#   inflating: food-10-mini/images/french_fries/2522964.jpg
#   inflating: food-10-mini/images/french_fries/2527291.jpg
#   inflating: food-10-mini/images/french_fries/2528360.jpg
#   inflating: food-10-mini/images/french_fries/2528368.jpg
#   inflating: food-10-mini/images/french_fries/2528860.jpg
#   inflating: food-10-mini/images/french_fries/2530422.jpg
#   inflating: food-10-mini/images/french_fries/2536896.jpg
#   inflating: food-10-mini/images/french_fries/2539272.jpg
#   inflating: food-10-mini/images/french_fries/2550720.jpg
#   inflating: food-10-mini/images/french_fries/2551910.jpg
#   inflating: food-10-mini/images/french_fries/256347.jpg
#   inflating: food-10-mini/images/french_fries/2565707.jpg
#   inflating: food-10-mini/images/french_fries/2569827.jpg
#   inflating: food-10-mini/images/french_fries/2572849.jpg
#   inflating: food-10-mini/images/french_fries/2573727.jpg
#   inflating: food-10-mini/images/french_fries/2576150.jpg
#   inflating: food-10-mini/images/french_fries/2580653.jpg
#   inflating: food-10-mini/images/french_fries/2586818.jpg
#   inflating: food-10-mini/images/french_fries/258877.jpg
#   inflating: food-10-mini/images/french_fries/2592571.jpg
#   inflating: food-10-mini/images/french_fries/2596038.jpg
#   inflating: food-10-mini/images/french_fries/2596850.jpg
#   inflating: food-10-mini/images/french_fries/2601877.jpg
#   inflating: food-10-mini/images/french_fries/2603436.jpg
#   inflating: food-10-mini/images/french_fries/2606474.jpg
#   inflating: food-10-mini/images/french_fries/2607081.jpg
#   inflating: food-10-mini/images/french_fries/2615826.jpg
#   inflating: food-10-mini/images/french_fries/2617942.jpg
#   inflating: food-10-mini/images/french_fries/2622969.jpg
#   inflating: food-10-mini/images/french_fries/2624022.jpg
#   inflating: food-10-mini/images/french_fries/2624207.jpg
#   inflating: food-10-mini/images/french_fries/2624567.jpg
#   inflating: food-10-mini/images/french_fries/2627843.jpg
#   inflating: food-10-mini/images/french_fries/2628143.jpg
#   inflating: food-10-mini/images/french_fries/262882.jpg
#   inflating: food-10-mini/images/french_fries/2630804.jpg
#   inflating: food-10-mini/images/french_fries/2631590.jpg
#   inflating: food-10-mini/images/french_fries/2632761.jpg
#   inflating: food-10-mini/images/french_fries/2634202.jpg
#   inflating: food-10-mini/images/french_fries/2637800.jpg
#   inflating: food-10-mini/images/french_fries/2641001.jpg
#   inflating: food-10-mini/images/french_fries/2641499.jpg
#   inflating: food-10-mini/images/french_fries/2644820.jpg
#   inflating: food-10-mini/images/french_fries/2649282.jpg
#   inflating: food-10-mini/images/french_fries/2649729.jpg
#   inflating: food-10-mini/images/french_fries/2650142.jpg
#   inflating: food-10-mini/images/french_fries/2652203.jpg
#   inflating: food-10-mini/images/french_fries/265743.jpg
#   inflating: food-10-mini/images/french_fries/2661646.jpg
#   inflating: food-10-mini/images/french_fries/2661893.jpg
#   inflating: food-10-mini/images/french_fries/266364.jpg
#   inflating: food-10-mini/images/french_fries/2664896.jpg
#   inflating: food-10-mini/images/french_fries/2672237.jpg
#   inflating: food-10-mini/images/french_fries/2676252.jpg
#   inflating: food-10-mini/images/french_fries/267713.jpg
#   inflating: food-10-mini/images/french_fries/2677445.jpg
#   inflating: food-10-mini/images/french_fries/2680169.jpg
#   inflating: food-10-mini/images/french_fries/2696740.jpg
#   inflating: food-10-mini/images/french_fries/2699989.jpg
#   inflating: food-10-mini/images/french_fries/2700217.jpg
#   inflating: food-10-mini/images/french_fries/2705078.jpg
#   inflating: food-10-mini/images/french_fries/2705623.jpg
#   inflating: food-10-mini/images/french_fries/2708723.jpg
#   inflating: food-10-mini/images/french_fries/2708944.jpg
#   inflating: food-10-mini/images/french_fries/2714782.jpg
#   inflating: food-10-mini/images/french_fries/2719269.jpg
#   inflating: food-10-mini/images/french_fries/2721807.jpg
#   inflating: food-10-mini/images/french_fries/2730558.jpg
#   inflating: food-10-mini/images/french_fries/2733482.jpg
#   inflating: food-10-mini/images/french_fries/2737860.jpg
#   inflating: food-10-mini/images/french_fries/2740844.jpg
#   inflating: food-10-mini/images/french_fries/274368.jpg
#   inflating: food-10-mini/images/french_fries/2752863.jpg
#   inflating: food-10-mini/images/french_fries/2755270.jpg
#   inflating: food-10-mini/images/french_fries/275673.jpg
#   inflating: food-10-mini/images/french_fries/2759016.jpg
#   inflating: food-10-mini/images/french_fries/2761796.jpg
#   inflating: food-10-mini/images/french_fries/2762026.jpg
#   inflating: food-10-mini/images/french_fries/2763839.jpg
#   inflating: food-10-mini/images/french_fries/2773035.jpg
#   inflating: food-10-mini/images/french_fries/2773760.jpg
#   inflating: food-10-mini/images/french_fries/2776614.jpg
#   inflating: food-10-mini/images/french_fries/2780060.jpg
#   inflating: food-10-mini/images/french_fries/2781602.jpg
#   inflating: food-10-mini/images/french_fries/2783225.jpg
#   inflating: food-10-mini/images/french_fries/2788061.jpg
#   inflating: food-10-mini/images/french_fries/2788461.jpg
#   inflating: food-10-mini/images/french_fries/2792575.jpg
#   inflating: food-10-mini/images/french_fries/2807320.jpg
#   inflating: food-10-mini/images/french_fries/2808737.jpg
#   inflating: food-10-mini/images/french_fries/2814658.jpg
#   inflating: food-10-mini/images/french_fries/2816416.jpg
#   inflating: food-10-mini/images/french_fries/2819952.jpg
#   inflating: food-10-mini/images/french_fries/2821467.jpg
#   inflating: food-10-mini/images/french_fries/2823656.jpg
#   inflating: food-10-mini/images/french_fries/2823700.jpg
#   inflating: food-10-mini/images/french_fries/2823936.jpg
#   inflating: food-10-mini/images/french_fries/2828062.jpg
#   inflating: food-10-mini/images/french_fries/2828656.jpg
#   inflating: food-10-mini/images/french_fries/2830352.jpg
#   inflating: food-10-mini/images/french_fries/2833974.jpg
#   inflating: food-10-mini/images/french_fries/2836915.jpg
#   inflating: food-10-mini/images/french_fries/2838364.jpg
#   inflating: food-10-mini/images/french_fries/2846402.jpg
#   inflating: food-10-mini/images/french_fries/2846809.jpg
#   inflating: food-10-mini/images/french_fries/2849981.jpg
#   inflating: food-10-mini/images/french_fries/2853342.jpg
#   inflating: food-10-mini/images/french_fries/2856271.jpg
#   inflating: food-10-mini/images/french_fries/2858185.jpg
#   inflating: food-10-mini/images/french_fries/2860811.jpg
#   inflating: food-10-mini/images/french_fries/2873652.jpg
#   inflating: food-10-mini/images/french_fries/2875570.jpg
#   inflating: food-10-mini/images/french_fries/2878424.jpg
#   inflating: food-10-mini/images/french_fries/2879174.jpg
#   inflating: food-10-mini/images/french_fries/2881817.jpg
#   inflating: food-10-mini/images/french_fries/2885926.jpg
#   inflating: food-10-mini/images/french_fries/2886781.jpg
#   inflating: food-10-mini/images/french_fries/2892637.jpg
#   inflating: food-10-mini/images/french_fries/2893262.jpg
#   inflating: food-10-mini/images/french_fries/2895439.jpg
#   inflating: food-10-mini/images/french_fries/2897469.jpg
#   inflating: food-10-mini/images/french_fries/2901457.jpg
#   inflating: food-10-mini/images/french_fries/2901987.jpg
#   inflating: food-10-mini/images/french_fries/2902107.jpg
#   inflating: food-10-mini/images/french_fries/290229.jpg
#   inflating: food-10-mini/images/french_fries/2903605.jpg
#   inflating: food-10-mini/images/french_fries/290382.jpg
#   inflating: food-10-mini/images/french_fries/2907806.jpg
#   inflating: food-10-mini/images/french_fries/2910032.jpg
#   inflating: food-10-mini/images/french_fries/2913911.jpg
#   inflating: food-10-mini/images/french_fries/2916251.jpg
#   inflating: food-10-mini/images/french_fries/2920371.jpg
#   inflating: food-10-mini/images/french_fries/292607.jpg
#   inflating: food-10-mini/images/french_fries/293052.jpg
#   inflating: food-10-mini/images/french_fries/2936284.jpg
#   inflating: food-10-mini/images/french_fries/2941321.jpg
#   inflating: food-10-mini/images/french_fries/2941901.jpg
#   inflating: food-10-mini/images/french_fries/2945149.jpg
#   inflating: food-10-mini/images/french_fries/2951206.jpg
#   inflating: food-10-mini/images/french_fries/2952319.jpg
#   inflating: food-10-mini/images/french_fries/2956615.jpg
#   inflating: food-10-mini/images/french_fries/2956993.jpg
#   inflating: food-10-mini/images/french_fries/2957806.jpg
#   inflating: food-10-mini/images/french_fries/2958833.jpg
#   inflating: food-10-mini/images/french_fries/2959500.jpg
#   inflating: food-10-mini/images/french_fries/2965155.jpg
#   inflating: food-10-mini/images/french_fries/296611.jpg
#   inflating: food-10-mini/images/french_fries/2967215.jpg
#   inflating: food-10-mini/images/french_fries/2971456.jpg
#   inflating: food-10-mini/images/french_fries/2972546.jpg
#   inflating: food-10-mini/images/french_fries/2979208.jpg
#   inflating: food-10-mini/images/french_fries/2982285.jpg
#   inflating: food-10-mini/images/french_fries/2984592.jpg
#   inflating: food-10-mini/images/french_fries/2984923.jpg
#   inflating: food-10-mini/images/french_fries/2986125.jpg
#   inflating: food-10-mini/images/french_fries/2989888.jpg
#   inflating: food-10-mini/images/french_fries/2991239.jpg
#   inflating: food-10-mini/images/french_fries/2991808.jpg
#   inflating: food-10-mini/images/french_fries/2993823.jpg
#   inflating: food-10-mini/images/french_fries/2998185.jpg
#   inflating: food-10-mini/images/french_fries/3002343.jpg
#   inflating: food-10-mini/images/french_fries/3002687.jpg
#   inflating: food-10-mini/images/french_fries/3010680.jpg
#   inflating: food-10-mini/images/french_fries/3012487.jpg
#   inflating: food-10-mini/images/french_fries/3021100.jpg
#   inflating: food-10-mini/images/french_fries/3022848.jpg
#   inflating: food-10-mini/images/french_fries/302329.jpg
#   inflating: food-10-mini/images/french_fries/3025133.jpg
#   inflating: food-10-mini/images/french_fries/3029784.jpg
#   inflating: food-10-mini/images/french_fries/3030315.jpg
#   inflating: food-10-mini/images/french_fries/3030853.jpg
#   inflating: food-10-mini/images/french_fries/303460.jpg
#   inflating: food-10-mini/images/french_fries/3037407.jpg
#   inflating: food-10-mini/images/french_fries/303809.jpg
#   inflating: food-10-mini/images/french_fries/3048661.jpg
#   inflating: food-10-mini/images/french_fries/3049746.jpg
#   inflating: food-10-mini/images/french_fries/3050068.jpg
#   inflating: food-10-mini/images/french_fries/3051679.jpg
#   inflating: food-10-mini/images/french_fries/3053028.jpg
#   inflating: food-10-mini/images/french_fries/3057602.jpg
#   inflating: food-10-mini/images/french_fries/3058426.jpg
#   inflating: food-10-mini/images/french_fries/3061304.jpg
#   inflating: food-10-mini/images/french_fries/3061458.jpg
#   inflating: food-10-mini/images/french_fries/3062501.jpg
#   inflating: food-10-mini/images/french_fries/3063044.jpg
#   inflating: food-10-mini/images/french_fries/3069345.jpg
#   inflating: food-10-mini/images/french_fries/3069835.jpg
#   inflating: food-10-mini/images/french_fries/3070998.jpg
#   inflating: food-10-mini/images/french_fries/3071320.jpg
#   inflating: food-10-mini/images/french_fries/3081058.jpg
#   inflating: food-10-mini/images/french_fries/3081685.jpg
#   inflating: food-10-mini/images/french_fries/3084187.jpg
#   inflating: food-10-mini/images/french_fries/309651.jpg
#   inflating: food-10-mini/images/french_fries/3099167.jpg
#   inflating: food-10-mini/images/french_fries/3102929.jpg
#   inflating: food-10-mini/images/french_fries/3103431.jpg
#   inflating: food-10-mini/images/french_fries/3114409.jpg
#   inflating: food-10-mini/images/french_fries/3116766.jpg
#   inflating: food-10-mini/images/french_fries/311779.jpg
#   inflating: food-10-mini/images/french_fries/3131190.jpg
#   inflating: food-10-mini/images/french_fries/3137998.jpg
#   inflating: food-10-mini/images/french_fries/3139.jpg
#   inflating: food-10-mini/images/french_fries/3139636.jpg
#   inflating: food-10-mini/images/french_fries/3141886.jpg
#   inflating: food-10-mini/images/french_fries/3145574.jpg
#   inflating: food-10-mini/images/french_fries/3152566.jpg
#   inflating: food-10-mini/images/french_fries/3152740.jpg
#   inflating: food-10-mini/images/french_fries/3153806.jpg
#   inflating: food-10-mini/images/french_fries/3156237.jpg
#   inflating: food-10-mini/images/french_fries/3159377.jpg
#   inflating: food-10-mini/images/french_fries/3167615.jpg
#   inflating: food-10-mini/images/french_fries/3171053.jpg
#   inflating: food-10-mini/images/french_fries/3184259.jpg
#   inflating: food-10-mini/images/french_fries/3185191.jpg
#   inflating: food-10-mini/images/french_fries/3190389.jpg
#   inflating: food-10-mini/images/french_fries/3194309.jpg
#   inflating: food-10-mini/images/french_fries/3194910.jpg
#   inflating: food-10-mini/images/french_fries/3195201.jpg
#   inflating: food-10-mini/images/french_fries/319830.jpg
#   inflating: food-10-mini/images/french_fries/3198786.jpg
#   inflating: food-10-mini/images/french_fries/3199467.jpg
#   inflating: food-10-mini/images/french_fries/320734.jpg
#   inflating: food-10-mini/images/french_fries/3210333.jpg
#   inflating: food-10-mini/images/french_fries/322067.jpg
#   inflating: food-10-mini/images/french_fries/3221251.jpg
#   inflating: food-10-mini/images/french_fries/3221561.jpg
#   inflating: food-10-mini/images/french_fries/3223529.jpg
#   inflating: food-10-mini/images/french_fries/3223668.jpg
#   inflating: food-10-mini/images/french_fries/3225836.jpg
#   inflating: food-10-mini/images/french_fries/3236925.jpg
#   inflating: food-10-mini/images/french_fries/3240152.jpg
#   inflating: food-10-mini/images/french_fries/3243064.jpg
#   inflating: food-10-mini/images/french_fries/3246331.jpg
#   inflating: food-10-mini/images/french_fries/3247750.jpg
#   inflating: food-10-mini/images/french_fries/3252577.jpg
#   inflating: food-10-mini/images/french_fries/3253011.jpg
#   inflating: food-10-mini/images/french_fries/3254182.jpg
#   inflating: food-10-mini/images/french_fries/3258500.jpg
#   inflating: food-10-mini/images/french_fries/3262272.jpg
#   inflating: food-10-mini/images/french_fries/3269823.jpg
#   inflating: food-10-mini/images/french_fries/3271075.jpg
#   inflating: food-10-mini/images/french_fries/3274074.jpg
#   inflating: food-10-mini/images/french_fries/3276703.jpg
#   inflating: food-10-mini/images/french_fries/3284906.jpg
#   inflating: food-10-mini/images/french_fries/3285020.jpg
#   inflating: food-10-mini/images/french_fries/3285362.jpg
#   inflating: food-10-mini/images/french_fries/3288825.jpg
#   inflating: food-10-mini/images/french_fries/3289454.jpg
#   inflating: food-10-mini/images/french_fries/3291587.jpg
#   inflating: food-10-mini/images/french_fries/3293202.jpg
#   inflating: food-10-mini/images/french_fries/3295921.jpg
#   inflating: food-10-mini/images/french_fries/3297902.jpg
#   inflating: food-10-mini/images/french_fries/3303188.jpg
#   inflating: food-10-mini/images/french_fries/3303220.jpg
#   inflating: food-10-mini/images/french_fries/3303248.jpg
#   inflating: food-10-mini/images/french_fries/3307428.jpg
#   inflating: food-10-mini/images/french_fries/3308469.jpg
#   inflating: food-10-mini/images/french_fries/3310979.jpg
#   inflating: food-10-mini/images/french_fries/3311203.jpg
#   inflating: food-10-mini/images/french_fries/3311926.jpg
#   inflating: food-10-mini/images/french_fries/331674.jpg
#   inflating: food-10-mini/images/french_fries/3317868.jpg
#   inflating: food-10-mini/images/french_fries/3319655.jpg
#   inflating: food-10-mini/images/french_fries/3322990.jpg
#   inflating: food-10-mini/images/french_fries/3323039.jpg
#   inflating: food-10-mini/images/french_fries/3323977.jpg
#   inflating: food-10-mini/images/french_fries/3324580.jpg
#   inflating: food-10-mini/images/french_fries/3325881.jpg
#   inflating: food-10-mini/images/french_fries/3327856.jpg
#   inflating: food-10-mini/images/french_fries/3327888.jpg
#   inflating: food-10-mini/images/french_fries/3329455.jpg
#   inflating: food-10-mini/images/french_fries/333385.jpg
#   inflating: food-10-mini/images/french_fries/3337777.jpg
#   inflating: food-10-mini/images/french_fries/3338239.jpg
#   inflating: food-10-mini/images/french_fries/3342829.jpg
#   inflating: food-10-mini/images/french_fries/3343500.jpg
#   inflating: food-10-mini/images/french_fries/3345305.jpg
#   inflating: food-10-mini/images/french_fries/3352770.jpg
#   inflating: food-10-mini/images/french_fries/3358729.jpg
#   inflating: food-10-mini/images/french_fries/3359887.jpg
#   inflating: food-10-mini/images/french_fries/3368541.jpg
#   inflating: food-10-mini/images/french_fries/3370087.jpg
#   inflating: food-10-mini/images/french_fries/3370703.jpg
#   inflating: food-10-mini/images/french_fries/3375984.jpg
#   inflating: food-10-mini/images/french_fries/3377570.jpg
#   inflating: food-10-mini/images/french_fries/338101.jpg
#   inflating: food-10-mini/images/french_fries/338259.jpg
#   inflating: food-10-mini/images/french_fries/3384067.jpg
#   inflating: food-10-mini/images/french_fries/3393664.jpg
#   inflating: food-10-mini/images/french_fries/3393816.jpg
#   inflating: food-10-mini/images/french_fries/3396115.jpg
#   inflating: food-10-mini/images/french_fries/3401318.jpg
#   inflating: food-10-mini/images/french_fries/3405511.jpg
#   inflating: food-10-mini/images/french_fries/340656.jpg
#   inflating: food-10-mini/images/french_fries/3416327.jpg
#   inflating: food-10-mini/images/french_fries/3417062.jpg
#   inflating: food-10-mini/images/french_fries/3420756.jpg
#   inflating: food-10-mini/images/french_fries/3423618.jpg
#   inflating: food-10-mini/images/french_fries/3426819.jpg
#   inflating: food-10-mini/images/french_fries/3427095.jpg
#   inflating: food-10-mini/images/french_fries/3435993.jpg
#   inflating: food-10-mini/images/french_fries/3437480.jpg
#   inflating: food-10-mini/images/french_fries/344097.jpg
#   inflating: food-10-mini/images/french_fries/3447353.jpg
#   inflating: food-10-mini/images/french_fries/3447608.jpg
#   inflating: food-10-mini/images/french_fries/3447747.jpg
#   inflating: food-10-mini/images/french_fries/3450772.jpg
#   inflating: food-10-mini/images/french_fries/348356.jpg
#   inflating: food-10-mini/images/french_fries/3483916.jpg
#   inflating: food-10-mini/images/french_fries/3484006.jpg
#   inflating: food-10-mini/images/french_fries/3495789.jpg
#   inflating: food-10-mini/images/french_fries/349846.jpg
#   inflating: food-10-mini/images/french_fries/3499831.jpg
#   inflating: food-10-mini/images/french_fries/3499988.jpg
#   inflating: food-10-mini/images/french_fries/3500811.jpg
#   inflating: food-10-mini/images/french_fries/3507251.jpg
#   inflating: food-10-mini/images/french_fries/3509699.jpg
#   inflating: food-10-mini/images/french_fries/3516519.jpg
#   inflating: food-10-mini/images/french_fries/3524964.jpg
#   inflating: food-10-mini/images/french_fries/3528931.jpg
#   inflating: food-10-mini/images/french_fries/353170.jpg
#   inflating: food-10-mini/images/french_fries/353437.jpg
#   inflating: food-10-mini/images/french_fries/3535015.jpg
#   inflating: food-10-mini/images/french_fries/3543947.jpg
#   inflating: food-10-mini/images/french_fries/3549099.jpg
#   inflating: food-10-mini/images/french_fries/3552493.jpg
#   inflating: food-10-mini/images/french_fries/3560911.jpg
#   inflating: food-10-mini/images/french_fries/3565195.jpg
#   inflating: food-10-mini/images/french_fries/3566836.jpg
#   inflating: food-10-mini/images/french_fries/3567317.jpg
#   inflating: food-10-mini/images/french_fries/3569228.jpg
#   inflating: food-10-mini/images/french_fries/3574519.jpg
#   inflating: food-10-mini/images/french_fries/3579283.jpg
#   inflating: food-10-mini/images/french_fries/357993.jpg
#   inflating: food-10-mini/images/french_fries/3583553.jpg
#   inflating: food-10-mini/images/french_fries/3586758.jpg
#   inflating: food-10-mini/images/french_fries/3596528.jpg
#   inflating: food-10-mini/images/french_fries/3598151.jpg
#   inflating: food-10-mini/images/french_fries/3600843.jpg
#   inflating: food-10-mini/images/french_fries/3614614.jpg
#   inflating: food-10-mini/images/french_fries/361733.jpg
#   inflating: food-10-mini/images/french_fries/3620351.jpg
#   inflating: food-10-mini/images/french_fries/3620996.jpg
#   inflating: food-10-mini/images/french_fries/3621286.jpg
#   inflating: food-10-mini/images/french_fries/3621856.jpg
#   inflating: food-10-mini/images/french_fries/3622622.jpg
#   inflating: food-10-mini/images/french_fries/3623578.jpg
#   inflating: food-10-mini/images/french_fries/3625607.jpg
#   inflating: food-10-mini/images/french_fries/3626100.jpg
#   inflating: food-10-mini/images/french_fries/3626463.jpg
#   inflating: food-10-mini/images/french_fries/3626833.jpg
#   inflating: food-10-mini/images/french_fries/3627636.jpg
#   inflating: food-10-mini/images/french_fries/3635674.jpg
#   inflating: food-10-mini/images/french_fries/3639861.jpg
#   inflating: food-10-mini/images/french_fries/3647571.jpg
#   inflating: food-10-mini/images/french_fries/3654244.jpg
#   inflating: food-10-mini/images/french_fries/3656250.jpg
#   inflating: food-10-mini/images/french_fries/3659782.jpg
#   inflating: food-10-mini/images/french_fries/3660458.jpg
#   inflating: food-10-mini/images/french_fries/3661409.jpg
#   inflating: food-10-mini/images/french_fries/3663095.jpg
#   inflating: food-10-mini/images/french_fries/366349.jpg
#   inflating: food-10-mini/images/french_fries/3669402.jpg
#   inflating: food-10-mini/images/french_fries/3673168.jpg
#   inflating: food-10-mini/images/french_fries/3673822.jpg
#   inflating: food-10-mini/images/french_fries/3674858.jpg
#   inflating: food-10-mini/images/french_fries/3677959.jpg
#   inflating: food-10-mini/images/french_fries/3678935.jpg
#   inflating: food-10-mini/images/french_fries/3681263.jpg
#   inflating: food-10-mini/images/french_fries/3681905.jpg
#   inflating: food-10-mini/images/french_fries/3684873.jpg
#   inflating: food-10-mini/images/french_fries/3688281.jpg
#   inflating: food-10-mini/images/french_fries/3688324.jpg
#   inflating: food-10-mini/images/french_fries/3697215.jpg
#   inflating: food-10-mini/images/french_fries/3698017.jpg
#   inflating: food-10-mini/images/french_fries/3700106.jpg
#   inflating: food-10-mini/images/french_fries/370033.jpg
#   inflating: food-10-mini/images/french_fries/3701352.jpg
#   inflating: food-10-mini/images/french_fries/370151.jpg
#   inflating: food-10-mini/images/french_fries/3708237.jpg
#   inflating: food-10-mini/images/french_fries/3708309.jpg
#   inflating: food-10-mini/images/french_fries/3709611.jpg
#   inflating: food-10-mini/images/french_fries/3711232.jpg
#   inflating: food-10-mini/images/french_fries/3711767.jpg
#   inflating: food-10-mini/images/french_fries/3714377.jpg
#   inflating: food-10-mini/images/french_fries/3714937.jpg
#   inflating: food-10-mini/images/french_fries/3719546.jpg
#   inflating: food-10-mini/images/french_fries/3724080.jpg
#   inflating: food-10-mini/images/french_fries/3724081.jpg
#   inflating: food-10-mini/images/french_fries/3728345.jpg
#   inflating: food-10-mini/images/french_fries/3730920.jpg
#   inflating: food-10-mini/images/french_fries/374001.jpg
#   inflating: food-10-mini/images/french_fries/3745147.jpg
#   inflating: food-10-mini/images/french_fries/3746805.jpg
#   inflating: food-10-mini/images/french_fries/3751241.jpg
#   inflating: food-10-mini/images/french_fries/375233.jpg
#   inflating: food-10-mini/images/french_fries/3754158.jpg
#   inflating: food-10-mini/images/french_fries/3759335.jpg
#   inflating: food-10-mini/images/french_fries/3762377.jpg
#   inflating: food-10-mini/images/french_fries/3764329.jpg
#   inflating: food-10-mini/images/french_fries/3765135.jpg
#   inflating: food-10-mini/images/french_fries/3772034.jpg
#   inflating: food-10-mini/images/french_fries/3784230.jpg
#   inflating: food-10-mini/images/french_fries/3790341.jpg
#   inflating: food-10-mini/images/french_fries/3794090.jpg
#   inflating: food-10-mini/images/french_fries/3795403.jpg
#   inflating: food-10-mini/images/french_fries/3806837.jpg
#   inflating: food-10-mini/images/french_fries/3813899.jpg
#   inflating: food-10-mini/images/french_fries/3817404.jpg
#   inflating: food-10-mini/images/french_fries/3818349.jpg
#   inflating: food-10-mini/images/french_fries/3826077.jpg
#   inflating: food-10-mini/images/french_fries/3830442.jpg
#   inflating: food-10-mini/images/french_fries/3832935.jpg
#   inflating: food-10-mini/images/french_fries/3832957.jpg
#   inflating: food-10-mini/images/french_fries/3835129.jpg
#   inflating: food-10-mini/images/french_fries/3842428.jpg
#   inflating: food-10-mini/images/french_fries/3843922.jpg
#   inflating: food-10-mini/images/french_fries/3854016.jpg
#   inflating: food-10-mini/images/french_fries/3857595.jpg
# ...
#   inflating: food-10-mini/images/sashimi/3469796.jpg
#   inflating: food-10-mini/images/sashimi/3475894.jpg
#   inflating: food-10-mini/images/sashimi/3478074.jpg
#   inflating: food-10-mini/images/sashimi/348340.jpg
#   inflating: food-10-mini/images/sashimi/3484663.jpg
#   inflating: food-10-mini/images/sashimi/3486887.jpg
#   inflating: food-10-mini/images/sashimi/3487018.jpg
#   inflating: food-10-mini/images/sashimi/3489088.jpg
#   inflating: food-10-mini/images/sashimi/3497187.jpg
#   inflating: food-10-mini/images/sashimi/3499966.jpg
#   inflating: food-10-mini/images/sashimi/3502521.jpg
#   inflating: food-10-mini/images/sashimi/3504509.jpg
#   inflating: food-10-mini/images/sashimi/3517101.jpg
#   inflating: food-10-mini/images/sashimi/351808.jpg
#   inflating: food-10-mini/images/sashimi/3523612.jpg
#   inflating: food-10-mini/images/sashimi/3524774.jpg
#   inflating: food-10-mini/images/sashimi/3534143.jpg
#   inflating: food-10-mini/images/sashimi/353448.jpg
#   inflating: food-10-mini/images/sashimi/3535789.jpg
#   inflating: food-10-mini/images/sashimi/353580.jpg
#   inflating: food-10-mini/images/sashimi/3536996.jpg
#   inflating: food-10-mini/images/sashimi/3537648.jpg
#   inflating: food-10-mini/images/sashimi/3541180.jpg
#   inflating: food-10-mini/images/sashimi/3542073.jpg
#   inflating: food-10-mini/images/sashimi/3546792.jpg
#   inflating: food-10-mini/images/sashimi/3548488.jpg
#   inflating: food-10-mini/images/sashimi/3557912.jpg
#   inflating: food-10-mini/images/sashimi/3564342.jpg
#   inflating: food-10-mini/images/sashimi/3565531.jpg
#   inflating: food-10-mini/images/sashimi/3566760.jpg
#   inflating: food-10-mini/images/sashimi/3571712.jpg
#   inflating: food-10-mini/images/sashimi/3575511.jpg
#   inflating: food-10-mini/images/sashimi/3585316.jpg
#   inflating: food-10-mini/images/sashimi/3589560.jpg
#   inflating: food-10-mini/images/sashimi/3591485.jpg
#   inflating: food-10-mini/images/sashimi/3592170.jpg
#   inflating: food-10-mini/images/sashimi/3593122.jpg
#   inflating: food-10-mini/images/sashimi/359575.jpg
#   inflating: food-10-mini/images/sashimi/3601803.jpg
#   inflating: food-10-mini/images/sashimi/3603470.jpg
#   inflating: food-10-mini/images/sashimi/360689.jpg
#   inflating: food-10-mini/images/sashimi/3607132.jpg
#   inflating: food-10-mini/images/sashimi/3608221.jpg
#   inflating: food-10-mini/images/sashimi/3608550.jpg
#   inflating: food-10-mini/images/sashimi/3619018.jpg
#   inflating: food-10-mini/images/sashimi/3619696.jpg
#   inflating: food-10-mini/images/sashimi/3621134.jpg
#   inflating: food-10-mini/images/sashimi/3628510.jpg
#   inflating: food-10-mini/images/sashimi/3628662.jpg
#   inflating: food-10-mini/images/sashimi/3637596.jpg
#   inflating: food-10-mini/images/sashimi/3643.jpg
#   inflating: food-10-mini/images/sashimi/3643177.jpg
#   inflating: food-10-mini/images/sashimi/3649758.jpg
#   inflating: food-10-mini/images/sashimi/3651022.jpg
#   inflating: food-10-mini/images/sashimi/3656158.jpg
#   inflating: food-10-mini/images/sashimi/365830.jpg
#   inflating: food-10-mini/images/sashimi/3659809.jpg
#   inflating: food-10-mini/images/sashimi/366355.jpg
#   inflating: food-10-mini/images/sashimi/3670207.jpg
#   inflating: food-10-mini/images/sashimi/3686273.jpg
#   inflating: food-10-mini/images/sashimi/3686799.jpg
#   inflating: food-10-mini/images/sashimi/3687952.jpg
#   inflating: food-10-mini/images/sashimi/3690211.jpg
#   inflating: food-10-mini/images/sashimi/3694198.jpg
#   inflating: food-10-mini/images/sashimi/3702185.jpg
#   inflating: food-10-mini/images/sashimi/3721022.jpg
#   inflating: food-10-mini/images/sashimi/3726368.jpg
#   inflating: food-10-mini/images/sashimi/3728978.jpg
#   inflating: food-10-mini/images/sashimi/3737136.jpg
#   inflating: food-10-mini/images/sashimi/374042.jpg
#   inflating: food-10-mini/images/sashimi/3742899.jpg
#   inflating: food-10-mini/images/sashimi/3763546.jpg
#   inflating: food-10-mini/images/sashimi/3766310.jpg
#   inflating: food-10-mini/images/sashimi/3774880.jpg
#   inflating: food-10-mini/images/sashimi/3781073.jpg
#   inflating: food-10-mini/images/sashimi/3781661.jpg
#   inflating: food-10-mini/images/sashimi/3783847.jpg
#   inflating: food-10-mini/images/sashimi/3784634.jpg
#   inflating: food-10-mini/images/sashimi/3794408.jpg
#   inflating: food-10-mini/images/sashimi/3798014.jpg
#   inflating: food-10-mini/images/sashimi/380023.jpg
#   inflating: food-10-mini/images/sashimi/3812801.jpg
#   inflating: food-10-mini/images/sashimi/381849.jpg
#   inflating: food-10-mini/images/sashimi/3820614.jpg
#   inflating: food-10-mini/images/sashimi/3822472.jpg
#   inflating: food-10-mini/images/sashimi/3824912.jpg
#   inflating: food-10-mini/images/sashimi/3826501.jpg
#   inflating: food-10-mini/images/sashimi/3827674.jpg
#   inflating: food-10-mini/images/sashimi/3837876.jpg
#   inflating: food-10-mini/images/sashimi/3847693.jpg
#   inflating: food-10-mini/images/sashimi/385510.jpg
#   inflating: food-10-mini/images/sashimi/3855478.jpg
#   inflating: food-10-mini/images/sashimi/386612.jpg
#   inflating: food-10-mini/images/sashimi/3870021.jpg
#   inflating: food-10-mini/images/sashimi/3881610.jpg
#   inflating: food-10-mini/images/sashimi/3884191.jpg
#   inflating: food-10-mini/images/sashimi/389223.jpg
#   inflating: food-10-mini/images/sashimi/3902474.jpg
#   inflating: food-10-mini/images/sashimi/3902483.jpg
#   inflating: food-10-mini/images/sashimi/3902509.jpg
#   inflating: food-10-mini/images/sashimi/3904748.jpg
#   inflating: food-10-mini/images/sashimi/3906648.jpg
#   inflating: food-10-mini/images/sashimi/3908376.jpg
#   inflating: food-10-mini/images/sashimi/3914732.jpg
#   inflating: food-10-mini/images/sashimi/3915149.jpg
#   inflating: food-10-mini/images/sashimi/3917202.jpg
#   inflating: food-10-mini/images/sashimi/391837.jpg
#   inflating: food-10-mini/images/sashimi/392169.jpg
#   inflating: food-10-mini/images/sashimi/3924539.jpg
#   inflating: food-10-mini/images/sashimi/397068.jpg
#   inflating: food-10-mini/images/sashimi/398699.jpg
#   inflating: food-10-mini/images/sashimi/399449.jpg
#   inflating: food-10-mini/images/sashimi/399989.jpg
#   inflating: food-10-mini/images/sashimi/402062.jpg
#   inflating: food-10-mini/images/sashimi/402669.jpg
#   inflating: food-10-mini/images/sashimi/41363.jpg
#   inflating: food-10-mini/images/sashimi/413640.jpg
#   inflating: food-10-mini/images/sashimi/415024.jpg
#   inflating: food-10-mini/images/sashimi/415059.jpg
#   inflating: food-10-mini/images/sashimi/41709.jpg
#   inflating: food-10-mini/images/sashimi/419011.jpg
#   inflating: food-10-mini/images/sashimi/44037.jpg
#   inflating: food-10-mini/images/sashimi/440672.jpg
#   inflating: food-10-mini/images/sashimi/442731.jpg
#   inflating: food-10-mini/images/sashimi/443554.jpg
#   inflating: food-10-mini/images/sashimi/44392.jpg
#   inflating: food-10-mini/images/sashimi/444167.jpg
#   inflating: food-10-mini/images/sashimi/445197.jpg
#   inflating: food-10-mini/images/sashimi/445747.jpg
#   inflating: food-10-mini/images/sashimi/44752.jpg
#   inflating: food-10-mini/images/sashimi/448013.jpg
#   inflating: food-10-mini/images/sashimi/449113.jpg
#   inflating: food-10-mini/images/sashimi/450172.jpg
#   inflating: food-10-mini/images/sashimi/460658.jpg
#   inflating: food-10-mini/images/sashimi/463156.jpg
#   inflating: food-10-mini/images/sashimi/472242.jpg
#   inflating: food-10-mini/images/sashimi/478708.jpg
#   inflating: food-10-mini/images/sashimi/479908.jpg
#   inflating: food-10-mini/images/sashimi/480776.jpg
#   inflating: food-10-mini/images/sashimi/487181.jpg
#   inflating: food-10-mini/images/sashimi/493281.jpg
#   inflating: food-10-mini/images/sashimi/497800.jpg
#   inflating: food-10-mini/images/sashimi/50156.jpg
#   inflating: food-10-mini/images/sashimi/514410.jpg
#   inflating: food-10-mini/images/sashimi/514546.jpg
#   inflating: food-10-mini/images/sashimi/515536.jpg
#   inflating: food-10-mini/images/sashimi/519310.jpg
#   inflating: food-10-mini/images/sashimi/519487.jpg
#   inflating: food-10-mini/images/sashimi/520085.jpg
#   inflating: food-10-mini/images/sashimi/520148.jpg
#   inflating: food-10-mini/images/sashimi/527164.jpg
#   inflating: food-10-mini/images/sashimi/531586.jpg
#   inflating: food-10-mini/images/sashimi/542334.jpg
#   inflating: food-10-mini/images/sashimi/543799.jpg
#   inflating: food-10-mini/images/sashimi/546338.jpg
#   inflating: food-10-mini/images/sashimi/547844.jpg
#   inflating: food-10-mini/images/sashimi/548609.jpg
#   inflating: food-10-mini/images/sashimi/553524.jpg
#   inflating: food-10-mini/images/sashimi/557481.jpg
#   inflating: food-10-mini/images/sashimi/558523.jpg
#   inflating: food-10-mini/images/sashimi/558644.jpg
#   inflating: food-10-mini/images/sashimi/559058.jpg
#   inflating: food-10-mini/images/sashimi/564762.jpg
#   inflating: food-10-mini/images/sashimi/570665.jpg
#   inflating: food-10-mini/images/sashimi/571736.jpg
#   inflating: food-10-mini/images/sashimi/574681.jpg
#   inflating: food-10-mini/images/sashimi/578475.jpg
#   inflating: food-10-mini/images/sashimi/578606.jpg
#   inflating: food-10-mini/images/sashimi/578661.jpg
#   inflating: food-10-mini/images/sashimi/581698.jpg
#   inflating: food-10-mini/images/sashimi/586438.jpg
#   inflating: food-10-mini/images/sashimi/587593.jpg
#   inflating: food-10-mini/images/sashimi/589583.jpg
#   inflating: food-10-mini/images/sashimi/591454.jpg
#   inflating: food-10-mini/images/sashimi/592131.jpg
#   inflating: food-10-mini/images/sashimi/596936.jpg
#   inflating: food-10-mini/images/sashimi/603901.jpg
#   inflating: food-10-mini/images/sashimi/607348.jpg
#   inflating: food-10-mini/images/sashimi/607605.jpg
#   inflating: food-10-mini/images/sashimi/6189.jpg
#   inflating: food-10-mini/images/sashimi/6191.jpg
#   inflating: food-10-mini/images/sashimi/6194.jpg
#   inflating: food-10-mini/images/sashimi/622274.jpg
#   inflating: food-10-mini/images/sashimi/623603.jpg
#   inflating: food-10-mini/images/sashimi/625243.jpg
#   inflating: food-10-mini/images/sashimi/62984.jpg
#   inflating: food-10-mini/images/sashimi/635080.jpg
#   inflating: food-10-mini/images/sashimi/640928.jpg
#   inflating: food-10-mini/images/sashimi/641255.jpg
#   inflating: food-10-mini/images/sashimi/648425.jpg
#   inflating: food-10-mini/images/sashimi/650230.jpg
#   inflating: food-10-mini/images/sashimi/652187.jpg
#   inflating: food-10-mini/images/sashimi/654402.jpg
#   inflating: food-10-mini/images/sashimi/661827.jpg
#   inflating: food-10-mini/images/sashimi/662582.jpg
#   inflating: food-10-mini/images/sashimi/665207.jpg
#   inflating: food-10-mini/images/sashimi/66549.jpg
#   inflating: food-10-mini/images/sashimi/665588.jpg
#   inflating: food-10-mini/images/sashimi/670889.jpg
#   inflating: food-10-mini/images/sashimi/672405.jpg
#   inflating: food-10-mini/images/sashimi/67294.jpg
#   inflating: food-10-mini/images/sashimi/676364.jpg
#   inflating: food-10-mini/images/sashimi/683651.jpg
#   inflating: food-10-mini/images/sashimi/685460.jpg
#   inflating: food-10-mini/images/sashimi/687481.jpg
#   inflating: food-10-mini/images/sashimi/688918.jpg
#   inflating: food-10-mini/images/sashimi/689606.jpg
#   inflating: food-10-mini/images/sashimi/691344.jpg
#   inflating: food-10-mini/images/sashimi/707913.jpg
#   inflating: food-10-mini/images/sashimi/713455.jpg
#   inflating: food-10-mini/images/sashimi/71495.jpg
#   inflating: food-10-mini/images/sashimi/716832.jpg
#   inflating: food-10-mini/images/sashimi/717905.jpg
#   inflating: food-10-mini/images/sashimi/724811.jpg
#   inflating: food-10-mini/images/sashimi/730221.jpg
#   inflating: food-10-mini/images/sashimi/731121.jpg
#   inflating: food-10-mini/images/sashimi/736976.jpg
#   inflating: food-10-mini/images/sashimi/737480.jpg
#   inflating: food-10-mini/images/sashimi/739133.jpg
#   inflating: food-10-mini/images/sashimi/744663.jpg
#   inflating: food-10-mini/images/sashimi/745308.jpg
#   inflating: food-10-mini/images/sashimi/749651.jpg
#   inflating: food-10-mini/images/sashimi/75049.jpg
#   inflating: food-10-mini/images/sashimi/751929.jpg
#   inflating: food-10-mini/images/sashimi/75250.jpg
#   inflating: food-10-mini/images/sashimi/753333.jpg
#   inflating: food-10-mini/images/sashimi/758154.jpg
#   inflating: food-10-mini/images/sashimi/761080.jpg
#   inflating: food-10-mini/images/sashimi/76496.jpg
#   inflating: food-10-mini/images/sashimi/766300.jpg
#   inflating: food-10-mini/images/sashimi/767866.jpg
#   inflating: food-10-mini/images/sashimi/76834.jpg
#   inflating: food-10-mini/images/sashimi/774590.jpg
#   inflating: food-10-mini/images/sashimi/774793.jpg
#   inflating: food-10-mini/images/sashimi/787756.jpg
#   inflating: food-10-mini/images/sashimi/790172.jpg
#   inflating: food-10-mini/images/sashimi/793068.jpg
#   inflating: food-10-mini/images/sashimi/79501.jpg
#   inflating: food-10-mini/images/sashimi/795596.jpg
#   inflating: food-10-mini/images/sashimi/802260.jpg
#   inflating: food-10-mini/images/sashimi/811266.jpg
#   inflating: food-10-mini/images/sashimi/8151.jpg
#   inflating: food-10-mini/images/sashimi/815841.jpg
#   inflating: food-10-mini/images/sashimi/821479.jpg
#   inflating: food-10-mini/images/sashimi/828846.jpg
#   inflating: food-10-mini/images/sashimi/829585.jpg
#   inflating: food-10-mini/images/sashimi/830435.jpg
#   inflating: food-10-mini/images/sashimi/832082.jpg
#   inflating: food-10-mini/images/sashimi/839585.jpg
#   inflating: food-10-mini/images/sashimi/840912.jpg
#   inflating: food-10-mini/images/sashimi/844328.jpg
#   inflating: food-10-mini/images/sashimi/844384.jpg
#   inflating: food-10-mini/images/sashimi/847915.jpg
#   inflating: food-10-mini/images/sashimi/852798.jpg
#   inflating: food-10-mini/images/sashimi/855965.jpg
#   inflating: food-10-mini/images/sashimi/860294.jpg
#   inflating: food-10-mini/images/sashimi/861444.jpg
#   inflating: food-10-mini/images/sashimi/87381.jpg
#   inflating: food-10-mini/images/sashimi/875629.jpg
#   inflating: food-10-mini/images/sashimi/881017.jpg
#   inflating: food-10-mini/images/sashimi/888437.jpg
#   inflating: food-10-mini/images/sashimi/889209.jpg
#   inflating: food-10-mini/images/sashimi/893381.jpg
#   inflating: food-10-mini/images/sashimi/895320.jpg
#   inflating: food-10-mini/images/sashimi/898609.jpg
#   inflating: food-10-mini/images/sashimi/899862.jpg
#   inflating: food-10-mini/images/sashimi/900344.jpg
#   inflating: food-10-mini/images/sashimi/902580.jpg
#   inflating: food-10-mini/images/sashimi/904903.jpg
#   inflating: food-10-mini/images/sashimi/923994.jpg
#   inflating: food-10-mini/images/sashimi/929528.jpg
#   inflating: food-10-mini/images/sashimi/934937.jpg
#   inflating: food-10-mini/images/sashimi/938288.jpg
#   inflating: food-10-mini/images/sashimi/945847.jpg
#   inflating: food-10-mini/images/sashimi/948670.jpg
#   inflating: food-10-mini/images/sashimi/951700.jpg
#   inflating: food-10-mini/images/sashimi/953486.jpg
#   inflating: food-10-mini/images/sashimi/9554.jpg
#   inflating: food-10-mini/images/sashimi/969197.jpg
#   inflating: food-10-mini/images/sashimi/977726.jpg
#   inflating: food-10-mini/images/sashimi/981801.jpg
#   inflating: food-10-mini/images/sashimi/983207.jpg
#   inflating: food-10-mini/images/sashimi/98340.jpg
#   inflating: food-10-mini/images/sashimi/987088.jpg
#   inflating: food-10-mini/images/sashimi/987318.jpg
#   inflating: food-10-mini/images/sashimi/988502.jpg
#   inflating: food-10-mini/images/sashimi/993162.jpg
#   inflating: food-10-mini/images/sashimi/994242.jpg
#   inflating: food-10-mini/license_agreement.txt
#    creating: food-10-mini/meta/
#   inflating: food-10-mini/meta/classes.txt
#   inflating: food-10-mini/meta/labels.txt
#   inflating: food-10-mini/meta/test.json
#   inflating: food-10-mini/meta/test.txt
#   inflating: food-10-mini/meta/train.json
#   inflating: food-10-mini/meta/train.txt
#   inflating: food-10-mini/README.txt

# %%
from collections import defaultdict
# Helper method to split dataset into train and test folders
from shutil import copy
def prepare_data(filepath, src, dest):
  classes_images = defaultdict(list)
  with open(filepath, 'r') as txt:
      paths = [read.strip() for read in txt.readlines()]
      for p in paths:
        food = p.split('/')
        classes_images[food[0]].append(food[1] + '.jpg')

  for food in classes_images.keys():
    print("\nCopying images into ",food)
    if not os.path.exists(os.path.join(dest,food)):
      os.makedirs(os.path.join(dest,food))
    for i in classes_images[food]:
      copy(os.path.join(src,food,i), os.path.join(dest,food,i))
  print("Copying Done!")

# %%
# %cd /content/deep_Mahalanobis_detector-V2/data/food-10-mini/
# Out:
# /content/deep_Mahalanobis_detector-V2/data/food-10-mini

# %%
# !pwd
# Out:
# /content/deep_Mahalanobis_detector-V2/data/food-10-mini

# %%
# Prepare train dataset by copying images from food-101/images to food-101/train using the file train.txt
print("Creating train data...")
prepare_data('./meta/train.txt', './images', './train')

# Prepare test data by copying images from food-101/images to food-101/test using the file test.txt
print("Creating test data...")
prepare_data('./meta/test.txt', './images', './test')
# Out:
# Creating train data...
#
# Copying images into  beef_carpaccio
#
# Copying images into  cheesecake
#
# Copying images into  club_sandwich
#
# Copying images into  deviled_eggs
#
# Copying images into  edamame
#
# Copying images into  french_fries
#
# Copying images into  hot_dog
#
# Copying images into  miso_soup
#
# Copying images into  oysters
#
# Copying images into  sashimi
# Copying Done!
# Creating test data...
#
# Copying images into  beef_carpaccio
#
# Copying images into  cheesecake
#
# Copying images into  club_sandwich
#
# Copying images into  deviled_eggs
#
# Copying images into  edamame
#
# Copying images into  french_fries
#
# Copying images into  hot_dog
#
# Copying images into  miso_soup
#
# Copying images into  oysters
#
# Copying images into  sashimi
# Copying Done!

# %%
# Data augmentation
train_transforms = transforms.Compose([transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.RandomVerticalFlip(),
                                       transforms.RandomRotation(45),
                                       transforms.RandomAffine(45),
                                       transforms.ColorJitter(),
                                       transforms.ToTensor(),
                                       transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                            std=[0.229, 0.224, 0.225])])

# Use 10-crop for Test Time Augmentation
test_transforms = transforms.Compose([transforms.Resize(256),
                                      transforms.TenCrop(224),
                                      transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])),
                                      transforms.Lambda(lambda crops: torch.stack([transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])(crop) for crop in crops]))])

# Load the datasets with ImageFolder
train_data = datasets.ImageFolder("/content/deep_Mahalanobis_detector-V2/data/food-10-mini/train", transform=train_transforms)
test_data = datasets.ImageFolder("/content/deep_Mahalanobis_detector-V2/data/food-10-mini/test", transform=train_transforms)

# Using the image datasets and the tranforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size = 64, shuffle = True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size= 64, shuffle = True)

# %%
# !pwd
# Out:
# /content/deep_Mahalanobis_detector-V2/data/food-10-mini

# %%
# Check how many files are in the train folder
print("Total number of samples in train folder")
# !find ./train -type d -or -type f -printf '.' | wc -c

# Check how many files are in the test folder
print("Total number of samples in test folder")
# !find ./test -type d -or -type f -printf '.' | wc -c
# Out:
# Total number of samples in train folder
# 7500
# Total number of samples in test folder
# 2500

# %%
from torchvision import datasets

cifar10_train = torch.utils.data.DataLoader(
    datasets.CIFAR10('/media/tadenoud/DATADisk/datasets/cifar10/', train=True,download = True, transform=in_transform),
    batch_size=64, num_workers=2, pin_memory=True)
    
cifar10_val = torch.utils.data.DataLoader(
    datasets.CIFAR10('/media/tadenoud/DATADisk/datasets/cifar10/', train=False,download = True, transform=in_transform),
    batch_size=64, num_workers=2, pin_memory=True)

svhn_val = torch.utils.data.DataLoader(
    datasets.SVHN('/media/tadenoud/DATADisk/datasets/svhn', split='test',download = True, transform=in_transform),
    batch_size=64, num_workers=2, pin_memory=True)

# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /media/tadenoud/DATADisk/datasets/cifar10/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting /media/tadenoud/DATADisk/datasets/cifar10/cifar-10-python.tar.gz to /media/tadenoud/DATADisk/datasets/cifar10/
# Files already downloaded and verified
# Downloading http://ufldl.stanford.edu/housenumbers/test_32x32.mat to /media/tadenoud/DATADisk/datasets/svhn/test_32x32.mat
# HBox(children=(FloatProgress(value=0.0, max=64275384.0), HTML(value='')))

# %%
print(len(train_loader))
# Out:
# 118

# %%
import torch.nn.functional as F
def penultimate_forward(model, x):
        out = F.relu(model.bn1(model.conv1(x)))
        out = model.layer1(out)
        out = model.layer2(out)
        out = model.layer3(out)
        penultimate = model.layer4(out)
        return penultimate

# %%
from tqdm.auto import tqdm

# Build the Mahalanobis Detector
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
all_features = np.empty((0,2048))
all_labels = np.empty(0)

for X, Y in tqdm(cifar10_train, total=len(cifar10_train)):
    X = X.to(device)
    # print(X.shape)
    features = penultimate_forward(model,X)
    
    features = features.view((features.size(0), features.size(1), -1))
    features = torch.mean(features, 2)
    
    features = features.detach().cpu().numpy()
    
    all_features = np.concatenate((all_features, features), axis=0)
    all_labels = np.concatenate((all_labels, Y.detach().cpu().numpy()), axis=0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))

# %%
num_classes = 10
import sklearn.covariance

def estimate_mahalanobis_parameters(features, labels, return_tensor=False):
    class_means = []
    centered_features = features.copy()

    for i in range(num_classes):
        mask = labels == i

        # Calculate the class mean
        class_means.append(features[mask].mean(axis=0))

        # Create mean subtracted features for covariance estimation
        centered_features[mask] -= class_means[i]


    # Calculate the inverted covariance matrix
    group_lasso = sklearn.covariance.EmpiricalCovariance(assume_centered=False)
    group_lasso.fit(centered_features)
    precision = group_lasso.precision_
    covariance = group_lasso.covariance_
    
    if return_tensor:
        class_means = torch.from_numpy(np.array(class_means)).float().cuda()
        precision = torch.from_numpy(precision).float().cuda()
        covariance = torch.from_numpy(covariance).float().cuda()
    
    return class_means, precision, covariance

# %%
class_means, precision, _ = estimate_mahalanobis_parameters(all_features, all_labels, return_tensor=True)

# %%
def mahalanobis_distance(features, means, inv_mahal_cov, device):   
    """Return a matrix with dist to each mean for each feature in the features batch."""
    # Tile the features and means to vectorize the operation
    num_means = means.shape[0]
    num_feats = features.shape[0]

    features = features.repeat(1, num_means).view(-1, features.shape[1])

    # subtract means in batches
    x = features - means.repeat(num_feats, 1)

    # matmul, take diagonal, then reshape
    dists = x.mm(inv_mahal_cov).mm(x.transpose(0,1)).diag()
    dists = dists.view(num_feats, num_means).transpose(0,1)

    min_dists, labels = dists.min(dim=0)
    return labels, min_dists


def get_mahalanobis_distances(model, class_means, precision, device, id_loader, ood_loader):
    """Get the distance to the nearest class_mean and return that distance and the class label for
        all data in the id_loader and ood_loader."""
    model.eval()
    min_dists = []
    labels = []
    
    with torch.no_grad():
        for data, target in tqdm(id_loader, total=len(id_loader)):
            data, target = data.to(device), target.to(device)
            features = penultimate_forward(model,data)
            features = features.view((features.size(0), features.size(1), -1))
            features = torch.mean(features, 2)
            pred, min_dist = mahalanobis_distance(features, class_means, precision, device)
            min_dists.append(min_dist.detach().cpu().numpy())
            labels.append(target.detach().cpu().numpy())
            
        for data, target in tqdm(ood_loader, total=len(ood_loader)):
            data, target = data.to(device), target.to(device)
            features = penultimate_forward(model,data)
            features = features.view((features.size(0), features.size(1), -1))
            features = torch.mean(features, 2)
            pred, min_dist = mahalanobis_distance(features, class_means, precision, device)
            min_dists.append(min_dist.detach().cpu().numpy())
            labels.append(np.ones(len(target)) * -1)
            
    return np.concatenate(min_dists), np.concatenate(labels)

# %%
dists, labels = get_mahalanobis_distances(model, class_means, precision, device, cifar10_val, svhn_val)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=157.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=407.0), HTML(value='')))

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone 'https://github.com/tayden/ood-metrics'
# Out:
# fatal: destination path 'ood-metrics' already exists and is not an empty directory.

# %%
# %cd /content/ood-metrics/
# Out:
# /content/ood-metrics

# %%
# %matplotlib inline

from ood_metrics import calc_metrics, plot_roc

labels[:10000] = 0
labels[10000:] = 1

plot_roc(dists, labels)
calc_metrics(dists, labels)
# Out:
# {'aupr_in': 0.33504296738161937,
#  'aupr_out': 0.7759631217583344,
#  'auroc': 0.5843270801321451,
#  'detection_error': 0.27742007104795735,
#  'fpr_at_95_tpr': 0.9239}
